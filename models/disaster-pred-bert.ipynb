# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

train = pd.read_csv('../train.csv')
test = pd.read_csv('../test.csv')
sumbission = pd.read_csv('../sample_submission.csv')

# %%
test.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
import re, string

class PreprocessText:
    def __init__(self, text):
        self.text = text 

    def remove_url(self, text):
        url = re.compile(r'https?://\S+|www\.\S+')
        return url.sub(r'', text)

    def remove_emoji(self, text):
        emoji_pattern = re.compile(
            '['
            u'\U0001F600-\U0001F64F'  # emoticons
            u'\U0001F300-\U0001F5FF'  # symbols & pictographs
            u'\U0001F680-\U0001F6FF'  # transport & map symbols
            u'\U0001F1E0-\U0001F1FF'  # flags (iOS)
            u'\U00002702-\U000027B0'
            u'\U000024C2-\U0001F251'
            ']+',
            flags=re.UNICODE)
        return emoji_pattern.sub(r'', text)

    def remove_html(self, text):
        html = re.compile(r'<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
        return re.sub(html, '', text)
    
    

    def clean_text(self):
        '''Make text lowercase, remove text in square brackets,remove links,remove punctuation
        and remove words containing numbers.'''
        text = str(self.text).lower()
        text = re.sub('\[.*?\]', '', text)
        text = re.sub('https?://\S+|www\.\S+', '', text)
        text = re.sub('<.*?>+', '', text)
        text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
        text = re.sub('\n', '', text)
        text = re.sub('\w*\d\w*', '', text)
        text = self.remove_url(text)
        text = self.remove_emoji(text)
        text = self.remove_html(text)
        return text

# %%
def preprocess(df):
    df = df.dropna(how="any", axis=1)
    df['clean_text'] = df['text'].apply(lambda x: PreprocessText(x).clean_text())
    df['text_len'] = df['text'].apply(lambda x: len(x.split(' ')))
    return df

# %%
train_df = preprocess(train)
test_df = preprocess(test)
train_df.head() 
# test_df.head()
# Out:
# C:\Users\HENRI_~1\AppData\Local\Temp/ipykernel_16024/2669824036.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['clean_text'] = df['text'].apply(lambda x: PreprocessText(x).clean_text())
# C:\Users\HENRI_~1\AppData\Local\Temp/ipykernel_16024/2669824036.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['clean_text'] = df['text'].apply(lambda x: PreprocessText(x).clean_text())
#    id                                               text  target  \
# 0   1  Our Deeds are the Reason of this #earthquake M...       1
# 1   4             Forest fire near La Ronge Sask. Canada       1
# 2   5  All residents asked to 'shelter in place' are ...       1
# 3   6  13,000 people receive #wildfires evacuation or...       1
# 4   7  Just got sent this photo from Ruby #Alaska as ...       1
#
#                                           clean_text  text_len
# 0  our deeds are the reason of this earthquake ma...        13
# 1              forest fire near la ronge sask canada         7
# 2  all residents asked to shelter in place are be...        22
# 3   people receive wildfires evacuation orders in...         9
# 4  just got sent this photo from ruby alaska as s...        17

# %%
from sklearn.model_selection import train_test_split

X = train_df.clean_text 
y = train_df.target

x_train, x_val, y_train, y_val = train_test_split(X, y, random_state=42)
print(len(x_train), len(y_train))
print(len(x_val), len(y_val))
# Out:
# 5709 5709
# 1904 1904

# %%
from transformers import AutoTokenizer

checkpoint = "vinai/bertweet-base"
checkpoint = "bert-large-uncased"

tokenizer = AutoTokenizer.from_pretrained(checkpoint, normalization=True)

# %%
x_train_input = dict(tokenizer(x_train.to_list(), padding=True, truncation=True, return_tensors="tf"))
x_val_input = dict(tokenizer(x_val.to_list(), padding=True, truncation=True, return_tensors="tf"))

x_test_input = dict(tokenizer(test_df.clean_text.to_list(), padding=True, truncation=True, return_tensors="tf"))

# %%
tokenizer.pad_token
# Out:
# '[PAD]'

# %%
from tensorflow.keras.metrics import Metric
import numpy as np


class F1_metric(Metric):
    def __init__(self, name='f1_score', **kwargs):
        super().__init__(name=name, **kwargs)
        # Initialize our metric by initializing the two metrics it's based on:
        # Precision and Recall
        self.precision = tf.keras.metrics.Precision()
        self.recall = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        # Update our metric by updating the two metrics it's based on
        self.precision.update_state(y_true, tf.math.argmax(y_pred, axis=0), sample_weight) # Ensure to get preds not logits 
        self.recall.update_state(y_true,tf.math.argmax(y_pred, axis=0), sample_weight)

    def reset_state(self):
        self.precision.reset_state()
        self.recall.reset_state()

    def result(self):
        # To get the F1 result, we compute the harmonic mean of the current
        # precision and recall
        return 2 / ((1 / self.precision.result()) + (1 / self.recall.result()))

# %%
# For tpu: 
import tensorflow as tf
import os

tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()

# instantiate a distribution strategy
strategy = tf.distribute.experimental.TPUStrategy(tpu)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\HENRI_~1\AppData\Local\Temp/ipykernel_16024/1379679066.py in <module>
#       3 import os
#       4
# ----> 5 tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
#       6
#       7 # instantiate a distribution strategy
#
# ~\miniconda3\envs\kaggle\lib\site-packages\tensorflow\python\distribute\cluster_resolver\tpu\tpu_cluster_resolver.py in connect(tpu, zone, project)
#      99       NotFoundError: If no TPU devices found in eager mode.
#     100     """
# --> 101     resolver = TPUClusterResolver(tpu, zone, project)
#     102     from tensorflow.python.eager import remote  # pylint: disable=g-import-not-at-top
#     103     remote.connect_to_cluster(resolver)
#
# ~\miniconda3\envs\kaggle\lib\site-packages\tensorflow\python\distribute\cluster_resolver\tpu\tpu_cluster_resolver.py in __init__(self, tpu, zone, project, job_name, coordinator_name, coordinator_address, credentials, service, discovery_url)
#     188     """
#     189
# --> 190     self._cloud_tpu_client = client.Client(
#     191         tpu=tpu,
#     192         zone=zone,
#
# ~\miniconda3\envs\kaggle\lib\site-packages\tensorflow\python\tpu\client\client.py in __init__(self, tpu, zone, project, credentials, service, discovery_url)
#     137
#     138     if tpu is None:
# --> 139       raise ValueError('Please provide a TPU Name to connect to.')
#     140
#     141     self._tpu = _as_text(tpu)
#
# ValueError: Please provide a TPU Name to connect to.

# %%
import numpy as np
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import PolynomialDecay
from transformers import TFAutoModelForSequenceClassification

batch_size = 16
# batch_size = 16 * strategy.num_replicas_in_sync

num_epochs = 5
num_train_steps = (len(x_train_input['input_ids']) // batch_size) * num_epochs

# Define lr_scheduler
lr_scheduler = PolynomialDecay(
    initial_learning_rate=5e-5,
    end_learning_rate=0.,
    decay_steps=num_train_steps
    )

# Define optimizer with lr_scheduler
opt = Adam(learning_rate=lr_scheduler)
loss = SparseCategoricalCrossentropy(from_logits=True)


with strategy.scope():
  model = TFAutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=2, return_dict=False) # TFAutoModel.from_pretrained(checkpoint)
  model.compile(optimizer=opt, loss=loss, metrics=['accuracy'])


model.fit(
    x_train_input,
    np.array(y_train), 
    validation_data=(
        x_val_input,
        np.array(y_val),
    ),
    batch_size=batch_size, 
    epochs=num_epochs
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\HENRI_~1\AppData\Local\Temp/ipykernel_16024/1518980693.py in <module>
#      24
#      25 # with strategy.scope():
# ---> 26 model = TFAutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=2, return_dict=False) # TFAutoModel.from_pretrained(checkpoint)
#      27 model.compile(optimizer=opt, loss=loss, metrics=['accuracy'])
#      28
#
# ~\miniconda3\envs\kaggle\lib\site-packages\transformers\modeling_tf_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    1045         for config_class, model_class in TF_MODEL_FOR_SEQUENCE_CLASSIFICATION_MAPPING.items():
#    1046             if isinstance(config, config_class):
# -> 1047                 return model_class.from_pretrained(pretrained_model_name_or_path, *model_args, config=config, **kwargs)
#    1048         raise ValueError(
#    1049             "Unrecognized configuration class {} for this kind of TFAutoModel: {}.\n"
#
# ~\miniconda3\envs\kaggle\lib\site-packages\transformers\modeling_tf_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     475
#     476         # Instantiate model.
# --> 477         model = cls(config, *model_args, **model_kwargs)
#     478
#     479         if from_pt:
#
# ~\miniconda3\envs\kaggle\lib\site-packages\transformers\modeling_tf_bert.py in __init__(self, config, *inputs, **kwargs)
#     905 class TFBertForSequenceClassification(TFBertPreTrainedModel, TFSequenceClassificationLoss):
#     906     def __init__(self, config, *inputs, **kwargs):
# --> 907         super().__init__(config, *inputs, **kwargs)
#     908         self.num_labels = config.num_labels
#     909
#
# ~\miniconda3\envs\kaggle\lib\site-packages\transformers\modeling_tf_utils.py in __init__(self, config, *inputs, **kwargs)
#     174
#     175     def __init__(self, config, *inputs, **kwargs):
# --> 176         super().__init__(*inputs, **kwargs)
#     177         if not isinstance(config, PretrainedConfig):
#     178             raise ValueError(
#
# ~\miniconda3\envs\kaggle\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\miniconda3\envs\kaggle\lib\site-packages\tensorflow\python\keras\engine\training.py in __init__(self, *args, **kwargs)
#     259     # self.trainable_weights
#     260     # self.non_trainable_weights
# --> 261     generic_utils.validate_kwargs(kwargs, {'trainable', 'dtype', 'dynamic',
#     262                                            'name', 'autocast'})
#     263     super(Model, self).__init__(**kwargs)
#
# ~\miniconda3\envs\kaggle\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py in validate_kwargs(kwargs, allowed_kwargs, error_message)
#     776   for kwarg in kwargs:
#     777     if kwarg not in allowed_kwargs:
# --> 778       raise TypeError(error_message, kwarg)
#     779
#     780
#
# TypeError: ('Keyword argument not understood:', 'num_labels')

# %%
ch = model(x_test_input, return_dict=True)

# %%
targets = [np.argmax(x) for x in ch['logits']]
# targets
ids = test.id.to_list()

# %%
submission = pd.DataFrame({'id': ids, 'target': targets})
submission.to_csv('submission.csv', index=False)
